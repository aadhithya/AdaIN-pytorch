# %%
import numpy as np
from PIL import Image
import sys
sys.path.append("../")
from data import VizDataset, ResizeShortest

from torchvision.datasets import ImageFolder
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.sampler import RandomSampler
import torchvision.transforms as tf

# %%
# Out:
# '/mnt/vol_b/mscoco/train2014/COCO_train2014_000000000009.jpg'

# %%
train_transform = tf.Compose(
        [
            ResizeShortest(128 * 2),
            tf.ToTensor(),
            tf.RandomCrop(128),
            # tf.Normalize(
            #     mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
            # ),
        ]
    )

# %%
c_ds = ImageFolder(
            "/mnt/vol_b/mscoco/", transform=train_transform
        )

# %%
len(c_ds)
# Out:
# 82783

# %%
c_dl = DataLoader(
            c_ds,
            batch_size=16,
            # sampler=RandomSampler(
            #     c_ds, replacement=True, num_samples=int(1e5)
            # ),
            num_workers=3,
        )

# %%
dl_it = iter(c_dl)

# %%
def dlt(dl_it):
    _ = dl_it.next()
    _ = dl_it.next()
    return

# %%
# %timeit dlt(dl_it)
# Out:
# 502 ms ± 128 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
data = dl_it.next()

# %%
len(data)
# Out:
# 2

# %%
data[0].shape
# Out:
# torch.Size([16, 3, 128, 128])

# %%
import matplotlib.pyplot as plt

# %%
data[0][2].shape
# Out:
# torch.Size([3, 128, 128])

# %%
img = data[0][2].permute(1,2,0)

# %%
img.shape
# Out:
# torch.Size([128, 128, 3])

# %%
plt.imshow(data[0][2].permute(1,2,0))
